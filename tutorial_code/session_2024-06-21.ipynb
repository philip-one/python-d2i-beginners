# %%
# you'll need to import a module
 
# https://github.com/data-to-insight/ERN-sessions/raw/main/data/903_xlsx_errors.xlsx
# read in EVERY sheet of the excel file
# start to have a look at/investigate the data

# %%
import pandas as pd
xlfilepath = r"https://github.com/data-to-insight/ERN-sessions/raw/main/data/903_xlsx_errors.xlsx"

sheets = pd.read_excel(xlfilepath, sheet_name=None)

# %%
print(sheets.keys())
for sname in sheets.keys():
    print("Sheet:", sname)
    sheets[sname].info()
# Out:
# dict_keys(['ad1', 'episodes', 'header', 'missing', 'oc2', 'oc3', 'placed_for_adoption', 'previous_permenance', 'reviews', 'uasc'])
# Sheet: ad1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CHILD        30 non-null     object
#  1   DOB          30 non-null     object
#  2   DATE_INT     30 non-null     object
#  3   DATE_MATCH   30 non-null     object
#  4   FOSTER_CARE  30 non-null     int64
#  5   NB_ADOPTR    30 non-null     object
#  6   SEX_ADOPTR   30 non-null     object
#  7   LS_ADOPTR    30 non-null     object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ KB
# Sheet: episodes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5050 entries, 0 to 5049
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   CHILD                5050 non-null   int64
#  1   DECOM                5050 non-null   object
#  2   RNE                  5050 non-null   object
#  3   LS                   5050 non-null   object
#  4   CIN                  5050 non-null   object
#  5   PLACE                5050 non-null   object
#  6   PLACE_PROVIDER       5050 non-null   object
#  7   DEC                  3637 non-null   object
#  8   REC                  5050 non-null   object
#  9   REASON_PLACE_CHANGE  2817 non-null   object
#  10  HOME_POST            5049 non-null   object
#  11  PL_POST              5049 non-null   object
#  12  URN                  5050 non-null   int64
# dtypes: int64(2), object(11)
# memory usage: 513.0+ KB
# Sheet: header
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CHILD   2676 non-null   object
#  1   SEX     2676 non-null   int64
#  2   DOB     2676 non-null   object
#  3   ETHNIC  2676 non-null   object
#  4   UPN     2676 non-null   object
#  5   MOTHER  1 non-null      float64
#  6   MC_DOB  1 non-null      object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 146.5+ KB
# Sheet: missing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CHILD      43 non-null     int64
#  1   DOB        43 non-null     object
#  2   MISSING    43 non-null     object
#  3   MIS_START  43 non-null     object
#  4   MIS_END    43 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.8+ KB
# Sheet: oc2
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2676 entries, 0 to 2675
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   CHILD                  2676 non-null   object
#  1   DOB                    2676 non-null   object
#  2   SDQ_SCORE              1322 non-null   object
#  3   SDQ_REASON             1355 non-null   object
#  4   CONVICTED              2676 non-null   object
#  5   HEALTH_CHECK           2676 non-null   object
#  6   IMMUNISATIONS          2676 non-null   object
#  7   TEETH_CHECK            2676 non-null   object
#  8   HEALTH_ASSESSMENT      2676 non-null   object
#  9   SUBSTANCE_MISUSE       2676 non-null   object
#  10  INTERVENTION_RECEIVED  2676 non-null   object
#  11  INTERVENTION_OFFERED   2676 non-null   object
# dtypes: object(12)
# memory usage: 251.0+ KB
# Sheet: oc3
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   CHILD     53 non-null     int64
#  1   DOB       53 non-null     object
#  2   IN_TOUCH  53 non-null     object
#  3   ACTIV     53 non-null     object
#  4   ACCOM     53 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.2+ KB
# Sheet: placed_for_adoption
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   CHILD                 30 non-null     object
#  1   DOB                   30 non-null     object
#  2   DATE_PLACED           30 non-null     object
#  3   DATE_PLACED_CEASED    30 non-null     object
#  4   REASON_PLACED_CEASED  30 non-null     object
# dtypes: object(5)
# memory usage: 1.3+ KB
# Sheet: previous_permenance
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2675 entries, 0 to 2674
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CHILD      2675 non-null   int64
#  1   DOB        2675 non-null   object
#  2   PREV_PERM  2675 non-null   object
#  3   LA_PERM    0 non-null      float64
#  4   DATE_PERM  0 non-null      float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 104.6+ KB
# Sheet: reviews
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12582 entries, 0 to 12581
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   CHILD        12582 non-null  int64
#  1   DOB          12582 non-null  object
#  2   REVIEW       12582 non-null  object
#  3   REVIEW_CODE  12582 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 393.3+ KB
# Sheet: uasc
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 132 entries, 0 to 131
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CHILD   132 non-null    int64
#  1   SEX     132 non-null    int64
#  2   DOB     132 non-null    object
#  3   DUC     132 non-null    object
# dtypes: int64(2), object(2)
# memory usage: 4.2+ KB

# %%
# 102 - date of birth is not a valid date
# .notna() / .isna()
 
header = sheets['header']
 
header['DOB'] = pd.to_datetime(header['DOB'], format="%d/%m/%Y", errors='coerce')
 
# invalid_dob = header['DOB'].isna()
# error_rows = header[invalid_dob]
 
valid_dob = header['DOB'].notna()
error_rows = header[~valid_dob]
 
error_rows
# Out:
#             CHILD  SEX DOB ETHNIC    UPN  MOTHER MC_DOB
# 2675  bad_entry_1    7 NaT  Alien  UPDOG     NaN    NaN

# %%
# 115 - Date of Local Authority's (LA) decision that a child should be placed 
#       for adoption is not a valid date.
# Table - placed_for_adoption
# column - DATE_PLACED

adoptees = sheets['placed_for_adoption']

adoptees['DATE_PLACED'] = pd.to_datetime(
    adoptees['DATE_PLACED'],
    format = "%d/%m/%Y", 
    errors='coerce'
)

invalid_placed_dates = adoptees['DATE_PLACED'].isna()
adoptees[invalid_placed_dates]
# Out:
#           CHILD         DOB DATE_PLACED      DATE_PLACED_CEASED  \
# 29  bad_entry_1  Not a date         NaT  This also isn't a date
#
#    REASON_PLACED_CEASED
# 29                  oop

# %%
# .isin()
# returns rows where the value is in a list of values
# value == another_value | value == another_another_value
 
# 103 - The ethnicity code is either not valid or has not been entered.
 
codes = [
        "WBRI",
        "WIRI",
        "WOTH",
        "WIRT",
        "WROM",
        "MWBC",
        "MWBA",
        "MWAS",
        "MOTH",
        "AIND",
        "APKN",
        "ABAN",
        "AOTH",
        "BCRB",
        "BAFR",
        "BOTH",
        "CHNE",
        "OOTH",
        "REFU",
        "NOBT",
    ]
 
valid_eth_codes = header['ETHNIC'].isin(codes)
 
error_rows = header[~valid_eth_codes]
 
error_rows
# Out:
#             CHILD  SEX DOB ETHNIC    UPN  MOTHER MC_DOB
# 2675  bad_entry_1    7 NaT  Alien  UPDOG     NaN    NaN

# %%
#114 - Data entry to record the status of former carer(s) of an adopted child is invalid.
# table is ad1, column is FOSTER_CARE, 0, 1

ad1 = sheets['ad1']

ad1['FOSTER_CARE'] = ad1['FOSTER_CARE'].astype('int')

valid_fostercare = ad1['FOSTER_CARE'].isin([0,1])
ad1[~valid_fostercare]
# Out:
#         CHILD       DOB DATE_INT DATE_MATCH  FOSTER_CARE NB_ADOPTR SEX_ADOPTR  \
# 29  bad_entry  datedate  notdate    datenot          777         Q       Will
#
#    LS_ADOPTR
# 29  let's go

# %%
# 184 - Date of decision that a child should be placed for adoption is before the child was born.
p4a = sheets['placed_for_adoption']
df = pd.merge(p4a.reset_index(), header, how='left', on='CHILD', suffixes=["_P4A", None])
 
invalid_date_placed = df['DATE_PLACED'] <= df['DOB']
 
error_rows = df[invalid_date_placed]
 
error_rows
# Out:
# Empty DataFrame
# Columns: [index, CHILD, DOB_P4A, DATE_PLACED, DATE_PLACED_CEASED, REASON_PLACED_CEASED, SEX, DOB, ETHNIC, UPN, MOTHER, MC_DOB]
# Index: []

# %%
# 302 - First episode starts before child was born.
# header, episodes, DOB from header, DECOM from episodes

episodes = sheets['episodes']
episodes['DECOM'] = pd.to_datetime(
    episodes['DECOM'],
    format = "%d/%m/%Y", 
    errors='coerce'
)

# %%
df = pd.merge(
    episodes.reset_index(), header, 
    how='left', on='CHILD', suffixes=['_ep', None]
)

prebirth_episodes = df['DECOM'] < df['DOB']
df[prebirth_episodes]
# Out:
# Empty DataFrame
# Columns: [index, CHILD, DECOM, RNE, LS, CIN, PLACE, PLACE_PROVIDER, DEC, REC, REASON_PLACE_CHANGE, HOME_POST, PL_POST, URN, SEX, DOB, ETHNIC, UPN, MOTHER, MC_DOB]
# Index: []

# %%
# 188 - Child is aged under 4 years at
# the end of the year but a Strengths and Difficulties (SDQ) score
# or a reason for no SDQ score has been completed
 
oc2 = sheets['oc2'][['CHILD', 'DOB', 'SDQ_SCORE', "SDQ_REASON"]].copy()
 
oc2['DOB'] = pd.to_datetime(oc2['DOB'], dayfirst=True, errors='coerce')
 
collection_end = pd.to_datetime("31/03/2020", dayfirst=True)
 
oc2['4bday'] = oc2['DOB'] + pd.DateOffset(years=4)
 
under_4 = oc2['4bday'] > collection_end
 
sdq_score_reason = oc2['SDQ_REASON'].notna() | oc2['SDQ_SCORE']
 
error_rows = oc2[under_4 & sdq_score_reason]
 
error_rows

# %%
# 189 - Child is aged 17 years or over at the beginning of the year,
#  but an Strengths and Difficulties (SDQ) score or a reason for no
# Strengths and Difficulties (SDQ) score has been completed.
# 01/04/2019

oc2 = sheets['oc2']
 
oc2['DOB'] = pd.to_datetime(oc2['DOB'], dayfirst=True, errors='coerce')

year_start = pd.to_datetime("01/04/2019", dayfirst=True)
 
oc2['17bday'] = oc2['DOB'] + pd.DateOffset(years=17)
 
over17 = oc2['17bday'] < year_start
 
sdq_score_reason = oc2['SDQ_REASON'].notna() | oc2['SDQ_SCORE']
 
error_rows = oc2[over17 & sdq_score_reason]
 
error_rows
# Out:
#        CHILD        DOB SDQ_SCORE SDQ_REASON CONVICTED HEALTH_CHECK  \
# 20    947046 2001-08-22       NaN       SDQ5         0            1
# 33    714655 2001-10-01       NaN       SDQ2         1            1
# 35    819792 2001-04-14        25        NaN         1            1
# 43    197474 2001-03-30         5        NaN         0            1
# 58    552166 2001-11-09        34        NaN         1            1
# ...      ...        ...       ...        ...       ...          ...
# 2634   97512 2001-12-27       NaN       SDQ1         0            0
# 2653  413076 2001-05-14        32        NaN         1            0
# 2659  482205 2001-04-26        32        NaN         1            0
# 2660  473732 2001-06-17       NaN       SDQ1         0            1
# 2667  558581 2001-07-05        37        NaN         0            1
#
#      IMMUNISATIONS TEETH_CHECK HEALTH_ASSESSMENT SUBSTANCE_MISUSE  \
# 20               0           1                 0                1
# 33               0           1                 1                0
# 35               1           1                 0                1
# 43               1           1                 0                1
# 58               1           1                 1                1
# ...            ...         ...               ...              ...
# 2634             1           0                 1                0
# 2653             1           0                 0                0
# 2659             0           0                 0                0
# 2660             0           1                 0                1
# 2667             0           0                 1                1
#
#      INTERVENTION_RECEIVED INTERVENTION_OFFERED     17bday
# 20                       0                    0 2018-08-22
# 33                       1                    0 2018-10-01
# 35                       1                    1 2018-04-14
# 43                       1                    0 2018-03-30
# 58                       1                    1 2018-11-09
# ...                    ...                  ...        ...
# 2634                     0                    1 2018-12-27
# 2653                     1                    1 2018-05-14
# 2659                     0                    0 2018-04-26
# 2660                     0                    0 2018-06-17
# 2667                     0                    1 2018-07-05
#
# [229 rows x 13 columns]

# %%
# 189 - Child is aged 17 years or over at the beginning of the year,
#  but an Strengths and Difficulties (SDQ) score or a reason for no
# Strengths and Difficulties (SDQ) score has been completed.
collection_start =  pd.to_datetime("01/04/2019", dayfirst=True)
 
over_17 = (oc2['DOB'] + pd.DateOffset(years=17)) < collection_start
 
error_rows = oc2[over_17 & sdq_score_reason]
 
error_rows
# Out:
#        CHILD        DOB SDQ_SCORE SDQ_REASON CONVICTED HEALTH_CHECK  \
# 20    947046 2001-08-22       NaN       SDQ5         0            1
# 33    714655 2001-10-01       NaN       SDQ2         1            1
# 35    819792 2001-04-14        25        NaN         1            1
# 43    197474 2001-03-30         5        NaN         0            1
# 58    552166 2001-11-09        34        NaN         1            1
# ...      ...        ...       ...        ...       ...          ...
# 2634   97512 2001-12-27       NaN       SDQ1         0            0
# 2653  413076 2001-05-14        32        NaN         1            0
# 2659  482205 2001-04-26        32        NaN         1            0
# 2660  473732 2001-06-17       NaN       SDQ1         0            1
# 2667  558581 2001-07-05        37        NaN         0            1
#
#      IMMUNISATIONS TEETH_CHECK HEALTH_ASSESSMENT SUBSTANCE_MISUSE  \
# 20               0           1                 0                1
# 33               0           1                 1                0
# 35               1           1                 0                1
# 43               1           1                 0                1
# 58               1           1                 1                1
# ...            ...         ...               ...              ...
# 2634             1           0                 1                0
# 2653             1           0                 0                0
# 2659             0           0                 0                0
# 2660             0           1                 0                1
# 2667             0           0                 1                1
#
#      INTERVENTION_RECEIVED INTERVENTION_OFFERED     17bday
# 20                       0                    0 2018-08-22
# 33                       1                    0 2018-10-01
# 35                       1                    1 2018-04-14
# 43                       1                    0 2018-03-30
# 58                       1                    1 2018-11-09
# ...                    ...                  ...        ...
# 2634                     0                    1 2018-12-27
# 2653                     1                    1 2018-05-14
# 2659                     0                    0 2018-04-26
# 2660                     0                    0 2018-06-17
# 2667                     0                    1 2018-07-05
#
# [229 rows x 13 columns]
